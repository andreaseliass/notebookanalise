# %% [markdown]
# <a href="https://colab.research.google.com/github/andreaseliass/notebookanalise/blob/main/Atividade_2_Semana_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Atividade 2 - Semana 3
# Nessa atividade foi usado um dataset do kaggle que pode ser encontrado em: https://www.kaggle.com/datasets/gregorut/videogamesales

# %%
# Carregando o dataset
data = pd.read_csv("/content/drive/MyDrive/Grupo DS/Semana 3/jogosconsole.csv")

# %%
data.info
# Out:
# <bound method DataFrame.info of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# O método abaixo retorna o tipo de cada coluna do dataset:

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#Acessando as colunas do dataset:
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
#Valores de determinada coluna:
data["Name"]
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
#Verificando algumas estatíticas resumidadas do dataset:
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#ordenando o dataset pela coluna "Global_Sales"
data.sort_values(by="Rank")
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Selecionando uma linha pela index
data.loc[100]
# Out:
# Rank                                               101
# Name            The Legend of Zelda: Twilight Princess
# Platform                                           Wii
# Year                                            2006.0
# Genre                                           Action
# Publisher                                     Nintendo
# NA_Sales                                          3.83
# EU_Sales                                          2.19
# JP_Sales                                           0.6
# Other_Sales                                        0.7
# Global_Sales                                      7.31
# Name: 100, dtype: object

# %%
#Selecionando linhas por critério condicional:
data[data["Year"] > 2010]
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 23        24                                 Grand Theft Auto V     X360
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 32        33                                Pokemon X/Pokemon Y      3DS
# 33        34                          Call of Duty: Black Ops 3      PS4
# ...      ...                                                ...      ...
# 16576  16579                                  Rugby Challenge 3     XOne
# 16578  16581                      Outdoors Unleashed: Africa 3D      3DS
# 16581  16584                                          Fit & Fun      Wii
# 16585  16588                                             Breach       PC
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year         Genre             Publisher  NA_Sales  EU_Sales  \
# ...

# %%
data[(data["Year"] > 2000) & (data["Global_Sales"] > 5)]
# Out:
#      Rank                                 Name Platform    Year     Genre  \
# 0       1                           Wii Sports      Wii  2006.0    Sports
# 2       3                       Mario Kart Wii      Wii  2008.0    Racing
# 3       4                    Wii Sports Resort      Wii  2009.0    Sports
# 6       7                New Super Mario Bros.       DS  2006.0  Platform
# 7       8                             Wii Play      Wii  2006.0      Misc
# ..    ...                                  ...      ...     ...       ...
# 196   197                      Resident Evil 5      PS3  2009.0    Action
# 197   198                   Grand Theft Auto V     XOne  2014.0    Action
# 198   199  Grand Theft Auto: Vice City Stories      PSP  2006.0    Action
# 199   200                       FIFA Soccer 11      PS3  2010.0    Sports
# 203   204  Super Smash Bros. for Wii U and 3DS     WiiU  2014.0  Fighting
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#visualizando primeiras linhas do dataset
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.head(15)
# Out:
#     Rank                         Name Platform    Year         Genre  \
# 0      1                   Wii Sports      Wii  2006.0        Sports
# 1      2            Super Mario Bros.      NES  1985.0      Platform
# 2      3               Mario Kart Wii      Wii  2008.0        Racing
# 3      4            Wii Sports Resort      Wii  2009.0        Sports
# 4      5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5      6                       Tetris       GB  1989.0        Puzzle
# 6      7        New Super Mario Bros.       DS  2006.0      Platform
# 7      8                     Wii Play      Wii  2006.0          Misc
# 8      9    New Super Mario Bros. Wii      Wii  2009.0      Platform
# 9     10                    Duck Hunt      NES  1984.0       Shooter
# 10    11                   Nintendogs       DS  2005.0    Simulation
# 11    12                Mario Kart DS       DS  2005.0        Racing
# 12    13  Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# ...

# %%
#exibindo as últimas linhas do dataset
data.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
data.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
#exibindo valores únicos de uma coluna
data["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
from pandas.core.frame import DataFrame
#verificando quantidades de cada gênero de jogos
data["Genre"].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
#valores de gêneros de jogos em porcentagem
data["Genre"].value_counts(normalize=True)
# Out:
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: Genre, dtype: float64

# %% [markdown]
# Pode-se observar que o gênero que tem maior número (ou porcentagem de jogos) são os jogos de ação.

# %%
#médias agrupadas pelos valores da coluna Gênero.
data.groupby("Genre").mean()
# Out:
#                       Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action         7973.879071  2007.909929  0.264726  0.158323  0.048236
# Adventure     11532.787714  2008.130878  0.082271  0.049868  0.040490
# Fighting       7646.511792  2004.630383  0.263667  0.119481  0.103007
# Misc           8561.847039  2007.258480  0.235906  0.124198  0.061967
# Platform       6927.251693  2003.820776  0.504571  0.227573  0.147596
# Puzzle         9627.381443  2005.243433  0.212680  0.087251  0.098471
# Racing         7961.515612  2004.840131  0.287766  0.190865  0.045388
# Role-Playing   8086.174731  2007.055744  0.219946  0.126384  0.236767
# Shooter        7369.367939  2005.918877  0.444733  0.239137  0.029221
# Simulation     8626.085352  2006.567568  0.211430  0.130773  0.073472
# Sports         7425.026428  2005.477865  0.291283  0.160635  0.057702
# Strategy      10071.897210  2005.599106  0.100881  0.066579  0.072628
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %%
data.dropna(how='any', inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
#Acabamos de remover as linhas que continham valores nulos, mas se quisérssemos ao invés de dropar 
#essas linhas, substituir os valores nulos por algum outro valor, usuríamos:
#data.fillna(99)

# %%
#Para sabermos quais valores estão nulos
data.isna()
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16286  False  False     False  False  False      False     False     False
# 16287  False  False     False  False  False      False     False     False
# 16288  False  False     False  False  False      False     False     False
# 16289  False  False     False  False  False      False     False     False
# 16290  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
#gráfico da distribuição de vendas de jogos ao longo dos anos
data["Year"].plot.hist()

# %%
data["Year"].plot.hist(bins=30, edgecolor='red')

# %%
#gráfico de barras
data["Genre"].value_counts().plot.bar()

# %%
data["Genre"].value_counts().plot.barh()

# %%
data["Genre"].value_counts().plot.barh(title="gêneros de jogos")

# %%
data.plot.scatter(x='Year', y='Global_Sales')

# %%
plt.style.use('ggplot')

# %%
data.plot.scatter(x='Year', y='Global_Sales')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
data["Genre"].value_counts().plot.pie()

# %%
#Quantidade de dados do dataset
data.size
# Out:
# 179201

# %%
#Quantidade de dados da coluna gênero
data.Genre.size
# Out:
# 16291

# %%
type(data['Year'])
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#observando que a coluna 'Year' está com tipo float, faz-se a conversão dele para int
data['Year'] = data['Year'].astype(int)

# %%
data.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#Número de linhas e de colunas do dataset
print('O dataset tem', data.shape[0], 'linhas')
print('O dataset tem', data.shape[1], 'colunas')
# Out:
# O dataset tem 16291 linhas
# O dataset tem 11 colunas

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16291, step=1)

# %%
display(data.head())
display(data.tail())
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
#         Rank                                              Name Platform  Year  \
# 16286  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# ...

# %%
data.loc[0:5, 'Year']
# Out:
# 0    2006
# 1    1985
# 2    2008
# 3    2009
# 4    1996
# 5    1989
# Name: Year, dtype: int64

# %%
data.iloc[0:5, 1:4]
# Out:
#                        Name Platform  Year
# 0                Wii Sports      Wii  2006
# 1         Super Mario Bros.      NES  1985
# 2            Mario Kart Wii      Wii  2008
# 3         Wii Sports Resort      Wii  2009
# 4  Pokemon Red/Pokemon Blue       GB  1996

# %%
x = data.query('Year>2000')
x.head()
# Out:
#    Rank                   Name Platform  Year     Genre Publisher  NA_Sales  \
# 0     1             Wii Sports      Wii  2006    Sports  Nintendo     41.49
# 2     3         Mario Kart Wii      Wii  2008    Racing  Nintendo     15.85
# 3     4      Wii Sports Resort      Wii  2009    Sports  Nintendo     15.75
# 6     7  New Super Mario Bros.       DS  2006  Platform  Nintendo     11.38
# 7     8               Wii Play      Wii  2006      Misc  Nintendo     14.03
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 6      9.23      6.50         2.90         30.01
# 7      9.20      2.93         2.85         29.02

# %%
data.filter(['Name', 'Year', 'Genre'])
# Out:
#                                                    Name  Year         Genre
# 0                                            Wii Sports  2006        Sports
# 1                                     Super Mario Bros.  1985      Platform
# 2                                        Mario Kart Wii  2008        Racing
# 3                                     Wii Sports Resort  2009        Sports
# 4                              Pokemon Red/Pokemon Blue  1996  Role-Playing
# ...                                                 ...   ...           ...
# 16286                Woody Woodpecker in Crazy Castle 5  2002      Platform
# 16287                     Men in Black II: Alien Escape  2003       Shooter
# 16288  SCORE International Baja 1000: The Official Game  2008        Racing
# 16289                                        Know How 2  2010        Puzzle
# 16290                                  Spirits & Spells  2003      Platform
#
# [16291 rows x 3 columns]

# %%
overall_median = data['Year'].median()
data.query("Year > @overall_median")
# Out:
#         Rank                                               Name Platform  \
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 14        15                                       Wii Fit Plus      Wii
# 15        16                                 Kinect Adventures!     X360
# ...      ...                                                ...      ...
# 16281  16591                                   Mega Brain Boost       DS
# 16282  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16285  16595                                           Plushees       DS
# 16288  16598   SCORE International Baja 1000: The Official Game      PS2
# 16289  16599                                         Know How 2       DS
#
#        Year       Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Ver se um determinado dado está no dataset
data[data['Name'].isin(['Mario Kart Wii', 'Wii Fit Plus'])]
# Out:
#     Rank            Name Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 2      3  Mario Kart Wii      Wii  2008  Racing  Nintendo     15.85     12.88
# 14    15    Wii Fit Plus      Wii  2009  Sports  Nintendo      9.09      8.59
#
#     JP_Sales  Other_Sales  Global_Sales
# 2       3.79         3.31         35.82
# 14      2.53         1.79         22.00

# %%
#retirando dados da lista
data2 = data[-data['Name'].isin(['Mario Kart Wii', 'Wii Fit Plus'])]

# %%
#ordenar dataset
data.sort_values(by='Year', ascending=False).head(10)
# Out:
#         Rank                                              Name Platform  Year  \
# 5860    5959                            Imagine: Makeup Artist       DS  2020
# 14136  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017
# 15944  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017
# 16135  16441                  Brothers Conflict: Precious Baby      PSV  2017
# 15924  16223                      Dynasty Warriors: Eiketsuden      PS4  2016
# 9811    9995                 Dead Island Definitive Collection      PS4  2016
# 5535    5623                                  TrackMania Turbo      PS4  2016
# 10541  10733                           Rise of the Tomb Raider       PC  2016
# 14587  14850                                          Terraria     WiiU  2016
# 13751  13996                           Destiny: The Collection     XOne  2016
#
#               Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#excluir valores duplicados
data.drop_duplicates()
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16286  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16287  16597                     Men in Black II: Alien Escape       GC  2003
# 16288  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16289  16599                                        Know How 2       DS  2010
# 16290  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
data.agg({'Year':['min', 'max', 'skew', 'median'],'Global_Sales':['min', 'max']})
# Out:
#                Year  Global_Sales
# min     1980.000000          0.01
# max     2020.000000         82.74
# skew      -1.003509           NaN
# median  2007.000000           NaN

# %%
data.groupby('Platform')['Year', 'Global_Sales'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                  Year  Global_Sales
# Platform
# 2600      1982.137931      0.746293
# 3DO       1994.666667      0.033333
# 3DS       2013.060120      0.493527
# DC        1999.942308      0.307115
# DS        2008.197560      0.384284
# GB        1995.958763      2.622887
# GBA       2003.175573      0.388830
# GC        2003.400369      0.363727
# GEN       1993.037037      1.050370
# GG        1992.000000      0.040000
# N64       1998.531646      0.690538
# NES       1987.153061      2.561939
# NG        1994.500000      0.120000
# PC        2008.763326      0.271535
# PCFX      1996.000000      0.030000
# PS        1998.004205      0.611766
# PS2       2004.583921      0.579906
# PS3       2010.819785      0.728029
# ...

# %%
#Quantidade de jogos por plataforma
data.Platform.value_counts()
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
#Quantidade de jogos por plataforma em porcentagem
data.Platform.value_counts(normalize=True)
# Out:
# DS      0.130808
# PS2     0.130563
# PS3     0.080044
# Wii     0.079185
# X360    0.075747
# PSP     0.073476
# PS      0.072985
# PC      0.057578
# XB      0.049291
# GBA     0.048247
# GC      0.033270
# 3DS     0.030630
# PSV     0.025167
# PS4     0.020625
# N64     0.019397
# SNES    0.014671
# XOne    0.013075
# SAT     0.010619
# WiiU    0.008778
# 2600    0.007120
# NES     0.006016
# GB      0.005954
# DC      0.003192
# GEN     0.001657
# NG      0.000737
# SCD     0.000368
# WS      0.000368
# 3DO     0.000184
# TG16    0.000123
# GG      0.000061
# PCFX    0.000061
# Name: Platform, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
data.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
#exportar csv
data.to_csv('data2.csv')

# %%
#gráfico de quantidade de jogos por plataforma
data.groupby(['Platform']).Platform.count().plot()

# %%
#gráfico de barras de quantidade de jogos por plataforma
data.groupby(['Platform']).Platform.count().sort_values()[-15:].plot(kind='bar')

# %%
data.boxplot()

# %%
data.plot.area()

# %%
data2 = pd.DataFrame(data, columns=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"])

data2.sum().plot.bar();

# %% [markdown]
# NA_Sales - Vendas - North America (em milhões)
#
# EU_Sales - Vendas - Europe (em milhões)
#
# JP_Sales - Vendas - Japan (em milhões)
#
# Other_Sales - Vendas - resto do mundo (em milhões)
#
# Aí podemos ver que o maior número de vendas foi na América do Norte, seguido pela Europa e Japão.

# %% [markdown]
# Mesmo plot na horizontal:

# %%
data2 = pd.DataFrame(data, columns=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"])

data2.sum().plot.barh();

# %%
data['Platform'].map('plataforma:{}'.format, na_action='ignore')
# Out:
# 0        plataforma:Wii
# 1        plataforma:NES
# 2        plataforma:Wii
# 3        plataforma:Wii
# 4         plataforma:GB
#               ...
# 16286    plataforma:GBA
# 16287     plataforma:GC
# 16288    plataforma:PS2
# 16289     plataforma:DS
# 16290    plataforma:GBA
# Name: Platform, Length: 16291, dtype: object

# %%
#Elevando valores das vendas globais ao quadrado
data['Global_Sales'].apply(np.square)
# Out:
# 0        6845.9076
# 1        1619.2576
# 2        1283.0724
# 3        1089.0000
# 4         984.0769
#            ...
# 16286       0.0001
# 16287       0.0001
# 16288       0.0001
# 16289       0.0001
# 16290       0.0001
# Name: Global_Sales, Length: 16291, dtype: float64

# %%
#Elevando valores das vendas globais ao quadrado de outra forma
data['Global_Sales'].apply(lambda x: x**2)
# Out:
# 0        6845.9076
# 1        1619.2576
# 2        1283.0724
# 3        1089.0000
# 4         984.0769
#            ...
# 16286       0.0001
# 16287       0.0001
# 16288       0.0001
# 16289       0.0001
# 16290       0.0001
# Name: Global_Sales, Length: 16291, dtype: float64

# %%
data_filtered = data[data['Platform'].isin(['PS4', 'XOne', 'Wii'])]
pd.pivot_table(data_filtered, index = 'Platform', values = ['EU_Sales',	'Global_Sales',	'JP_Sales',	'NA_Sales',	'Other_Sales'], aggfunc=np.mean)
# Out:
#           EU_Sales  Global_Sales  JP_Sales  NA_Sales  Other_Sales
# Platform
# PS4       0.368155      0.827679  0.042560  0.288095     0.129048
# Wii       0.204922      0.705279  0.052930  0.385558     0.061395
# XOne      0.214319      0.662254  0.001596  0.390563     0.055962
